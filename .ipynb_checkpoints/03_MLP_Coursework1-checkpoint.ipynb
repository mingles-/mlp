# %% [markdown]
# # Coursework #1
#
# ## Introduction
#
# This coursework is concerned with building multi-layer networks to address the MNIST digit classification problem. It builds on the previous labs, in particular [02_MNIST_SLN.ipynb](02_MNIST_SLN.ipynb) in which single layer networks were trained for MNIST digit classification.   The course will involve extending that code to use Sigmoid and Softmax layers, combining these into multi-layer networks, and carrying out a number of MNIST digit classification experiments, to investigate the effect of learning rate, the number of hidden units, and the number of hidden layers.
#
# The coursework is divided into 4 tasks:
# * **Task 1**:   *Implementing a sigmoid layer* - 15 marks.
# This task involves extending the `Linear` class in file `mlp/layers.py` to `Sigmoid`, with code for forward prop, backprop computation of the gradient, and weight update.
# * **Task 2**:  *Implementing a softmax layer* - 15 marks.
# This task involves extending the `Linear` class in file `mlp/layers.py` to `Softmax`, with code for forward prop, backprop computation of the gradient, and weight update.
# * **Task 3**:  *Constructing a multi-layer network* - 40 marks.
# This task involves putting together a Sigmoid and a Softmax layer to create a multi-layer network, with one hidden layer (100 units) and one output layer, that is trained to classify MNIST digits.  This task will include reporting classification results, exploring the effect of learning rates, and plotting Hinton Diagrams for the hidden units and output units.
# * **Task 4**:  *Experiments with different architectures*  - 30 marks.
# This task involves further MNIST classification experiments, primarily looking at the effect of using different numbers of hidden layers.
# The coursework will be marked out of 100, and will contribute 30% of the total mark in the MLP course.
#
# ## Previous Tutorials
#
# Before starting this coursework make sure that you have completed the first three labs:
#
# * [00_Introduction.ipynb](00_Introduction.ipynb) - setting up your environment; *Solutions*: [00_Introduction_solution.ipynb](00_Introduction_solution.ipynb)
# * [01_Linear_Models.ipynb](01_Linear_Models.ipynb) - training single layer networks; *Solutions*: [01_Linear_Models_solution.ipynb](01_Linear_Models_solution.ipynb)
# * [02_MNIST_SLN.ipynb](02_MNIST_SLN.ipynb) - training a single layer network for MNIST digit classification
#
# To ensure that your virtual environment is correct, please see [this note](https://github.com/CSTR-Edinburgh/mlpractical/blob/master/kernel_issue_fix.md) on the GitHub.
# ## Submission
# **Submission Deadline:  Thursday 29 October, 16:00**
#
# Submit the coursework as an ipython notebook file, using the `submit` command in the terminal on a DICE machine. If your file is `03_MLP_Coursework1.ipynb` then you would enter:
#
# `submit mlp 1 03_MLP_Coursework1.ipynb`
#
# where `mlp 1` indicates this is the first coursework of MLP.
#
# After submitting, you should receive an email of acknowledgment from the system confirming that your submission has been received successfully. Keep the email as evidence of your coursework submission.
#
# **Please make sure you submit a single `ipynb` file (and nothing else)!**
#
# **Submission Deadline:  Thursday 29 October, 16:00**

# %% [markdown]
# ## Getting Started
# Please enter your exam number and the date in the next code cell.

# %%
#MLP Coursework 1
#Exam number: B035680
#Date: 19.10.2015

# %% [markdown]
# Please run the next code cell, which imports `numpy` and seeds the random number generator.  Please **do not** modify the random number generator seed!

# %%
import numpy

#Seed a random number generator running the below cell, but do **not** modify the seed.
rng = numpy.random.RandomState([2015,10,10])
rng_state = rng.get_state()

# %% [markdown]
# ## Task 1 - Sigmoid Layer (15%)
#
# In this task you need to create a class `Sigmoid` which encapsulates a layer of sigmoid units.  You should do this by extending the `mlp.layers.Linear` class (in file `mlp/layers.py`), which implements a a layer of linear units (i.e. weighted sum plus bias).  The `Sigmoid` class extends this by applying the sigmoid transfer function to the weighted sum in the forward propagation, and applying the derivative of the sigmoid in the gradient descent back propagation and computing the gradients with respect to layer's parameters. Do **not** copy the implementation provided in `Linear` class but rather, **reuse** it through inheritance.
#
# When you have implemented `Sigmoid` (in the `mlp.layers` module), then please test it by running the below code cell.

# %%
from mlp.layers import Sigmoid

a = numpy.asarray([-20.1, 52.4, 0, 0.05, 0.05, 49])
b = numpy.asarray([-20.1, 52.4, 0, 0.05, 0.05, 49, 20, 20])

rng.set_state(rng_state)
sigm = Sigmoid(idim=a.shape[0], odim=b.shape[0], rng=rng)

fp = sigm.fprop(a)
deltas, ograds  = sigm.bprop(h=fp, igrads=b)

print fp.sum()
print deltas.sum()
print ograds.sum()
# %precision 3
print fp
print deltas
print ograds
# Out:
# 4.21941537867
# 25.9255147706
# 4.1105500626
# [ 0.067  0.728  0.999  0.512  0.159  0.584  0.238  0.932]
# [ -1.263e+00   1.037e+01   0.000e+00   1.249e-02   6.678e-03   1.191e+01
#    3.628e+00   1.268e+00]
# [ 1.406  0.078 -0.268  0.418  1.646  0.831]

# %% [markdown]
# ***
# To include the `Sigmoid` code in the notebook please run the below code cell.  (The `%load` notebook command is used to load the source of the `Sigmoid` class from `mlp/layers.py`.)

# %%
# %load -s Sigmoid mlp/layers.py
class Sigmoid(Linear):

    def sigmoid(self, z):

        the_sigmoid = 1.0 / (1 + numpy.exp(-z))
        return the_sigmoid

    def sigmoid_derivative(self, number):

        the_sigmoid_derivative = number * (1 - number)
        return the_sigmoid_derivative

    def fprop(self, inputs):

        a = numpy.dot(inputs, self.W) + self.b

        return self.sigmoid(a)

    def bprop(self, h, igrads):

        delta = igrads * numpy.vectorize(self.sigmoid_derivative, otypes=[numpy.float])(h)
        ograds = numpy.dot(delta, self.W.T)

        return delta, ograds

        
    def get_name(self):
        return 'sigmoid'

# %% [markdown]
# ## Task 2 - Softmax (15%)
#
# In this task you need to create a class `Softmax` which encapsulates a layer of softmax units.  As in the previous task, you should do this by extending the `mlp.layers.Linear` class (in file `mlp/layers.py`).
#
# When you have implemented `Softmax` (in the `mlp.layers` module), then please test it by running the below code cell.

# %%
from mlp.layers import Softmax

a = numpy.asarray([-20.1, 52.4, 0, 0.05, 0.05, 49])
b = numpy.asarray([0, 0, 0, 0, 0, 0, 0, 1])

rng.set_state(rng_state)
softmax = Softmax(idim=a.shape[0], odim=b.shape[0], rng=rng)

fp = softmax.fprop(a)
deltas, ograds = softmax.bprop_cost(h=None, igrads=fp-b, cost=None)

print fp.sum()
print deltas.sum()
print ograds.sum()
# %precision 3
print fp
print deltas
print ograds
# Out:
# 1.0
# 0.0
# 0.0744177068753
# [  4.571e-05   1.697e-03   9.877e-01   6.631e-04   1.194e-04   8.880e-04
#    1.977e-04   8.671e-03]
# [  4.571e-05   1.697e-03   9.877e-01   6.631e-04   1.194e-04   8.880e-04
#    1.977e-04  -9.913e-01]
# [-0.089  0.03   0.079  0.011  0.017  0.027]

# %% [markdown]
# ***
# To include the `Softmax` code in the notebook please run the below code cell.  (The notebook `%load` command is used to load the source of the `Softmax` class from `mlp/layers.py`.)

# %%
# %load -s Softmax mlp/layers.py

# %% [markdown]
# ## Task 3 - Multi-layer network for MNIST classification (40%)
#
# **(a)** (20%)  Building on the single layer linear network for MNIST classification used in lab [02_MNIST_SLN.ipynb](02_MNIST_SLN.ipynb), and using the `Sigmoid` and `Softmax` classes that you implemented in tasks 1 and 2, construct and learn a model that classifies MNIST images and:
#    * Has one hidden layer with a sigmoid transfer function and 100 units
#    * Uses a softmax output layer to discriminate between the 10 digit classes (use the `mlp.costs.CECost()` cost)
#
# Your code should print the final values of the error function and the classification accuracy for train, validation, and test sets (please keep also the log information printed by default by the optimiser). Limit the number of training epochs to 30. You can, of course, split your code across as many cells as you think is necessary.

# %%
# include here the complete code that constructs the model, performs training,
# and prints the error and accuracy for train/valid/test

import numpy
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

from mlp.layers import MLP, Linear, Sigmoid, Softmax #import required layer types
from mlp.optimisers import SGDOptimiser #import the optimiser
from mlp.dataset import MNISTDataProvider #import data provider
from mlp.costs import MSECost, CECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed

# define the model structure, here just one linear layer
# and mean square error cost
cost = CECost()
model = MLP(cost=cost)
model.add_layer(Sigmoid(idim=784, odim=100, rng=rng))
model.add_layer(Softmax(idim=100, odim=10, rng=rng))
#one can stack more layers here

# define the optimiser, here stochasitc gradient descent
# with fixed learning rate and max_epochs as stopping criterion
lr_scheduler = LearningRateFixed(learning_rate=0.01, max_epochs=30)
optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

logger.info('Initialising data providers...')
train_dp = MNISTDataProvider(dset='train', batch_size=100, max_num_batches=-10, randomize=True)
valid_dp = MNISTDataProvider(dset='valid', batch_size=100, max_num_batches=-10, randomize=False)

logger.info('Training started...')
optimiser.train(model, train_dp, valid_dp)

logger.info('Testing the model on test set:')
test_dp = MNISTDataProvider(dset='eval', batch_size=100, max_num_batches=-10, randomize=False)
cost, accuracy = optimiser.validate(model, test_dp)
logger.info('MNIST test set accuracy is %.2f %% (cost is %.3f)'%(accuracy*100., cost))
# Out:
# INFO:root:Initialising data providers...
# INFO:root:Training started...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for random model is 2.364. Accuracy is 8.62%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for random model is 2.362. Accuracy is 8.75%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 2.217. Accuracy is 34.95%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 2.107. Accuracy is 51.97%
# INFO:mlp.optimisers:Epoch 1: Took 4 seconds. Training speed 12748 pps. Validation speed 83461 pps.
# INFO:mlp.optimisers:Epoch 2: Training cost (ce) is 1.976. Accuracy is 60.83%
# INFO:mlp.optimisers:Epoch 2: Validation cost (ce) is 1.813. Accuracy is 70.66%
# INFO:mlp.optimisers:Epoch 2: Took 4 seconds. Training speed 12749 pps. Validation speed 84862 pps.
# INFO:mlp.optimisers:Epoch 3: Training cost (ce) is 1.653. Accuracy is 69.72%
# INFO:mlp.optimisers:Epoch 3: Validation cost (ce) is 1.464. Accuracy is 75.49%
# INFO:mlp.optimisers:Epoch 3: Took 4 seconds. Training speed 12785 pps. Validation speed 83332 pps.
# INFO:mlp.optimisers:Epoch 4: Training cost (ce) is 1.334. Accuracy is 75.13%
# INFO:mlp.optimisers:Epoch 4: Validation cost (ce) is 1.172. Accuracy is 79.49%
# INFO:mlp.optimisers:Epoch 4: Took 4 seconds. Training speed 12748 pps. Validation speed 83560 pps.
# INFO:mlp.optimisers:Epoch 5: Training cost (ce) is 1.093. Accuracy is 78.96%
# INFO:mlp.optimisers:Epoch 5: Validation cost (ce) is 0.967. Accuracy is 82.60%
# INFO:mlp.optimisers:Epoch 5: Took 4 seconds. Training speed 13031 pps. Validation speed 83051 pps.
# INFO:mlp.optimisers:Epoch 6: Training cost (ce) is 0.928. Accuracy is 81.30%
# INFO:mlp.optimisers:Epoch 6: Validation cost (ce) is 0.827. Accuracy is 84.22%
# INFO:mlp.optimisers:Epoch 6: Took 4 seconds. Training speed 12835 pps. Validation speed 79863 pps.
# INFO:mlp.optimisers:Epoch 7: Training cost (ce) is 0.813. Accuracy is 82.88%
# INFO:mlp.optimisers:Epoch 7: Validation cost (ce) is 0.728. Accuracy is 85.31%
# INFO:mlp.optimisers:Epoch 7: Took 4 seconds. Training speed 12642 pps. Validation speed 82557 pps.
# INFO:mlp.optimisers:Epoch 8: Training cost (ce) is 0.730. Accuracy is 84.00%
# INFO:mlp.optimisers:Epoch 8: Validation cost (ce) is 0.656. Accuracy is 86.10%
# INFO:mlp.optimisers:Epoch 8: Took 4 seconds. Training speed 12931 pps. Validation speed 82981 pps.
# INFO:mlp.optimisers:Epoch 9: Training cost (ce) is 0.668. Accuracy is 84.86%
# INFO:mlp.optimisers:Epoch 9: Validation cost (ce) is 0.602. Accuracy is 86.97%
# INFO:mlp.optimisers:Epoch 9: Took 4 seconds. Training speed 12716 pps. Validation speed 72565 pps.
# INFO:mlp.optimisers:Epoch 10: Training cost (ce) is 0.620. Accuracy is 85.59%
# INFO:mlp.optimisers:Epoch 10: Validation cost (ce) is 0.560. Accuracy is 87.40%
# INFO:mlp.optimisers:Epoch 10: Took 4 seconds. Training speed 12783 pps. Validation speed 86373 pps.
# INFO:mlp.optimisers:Epoch 11: Training cost (ce) is 0.582. Accuracy is 86.20%
# INFO:mlp.optimisers:Epoch 11: Validation cost (ce) is 0.525. Accuracy is 87.93%
# INFO:mlp.optimisers:Epoch 11: Took 4 seconds. Training speed 12959 pps. Validation speed 85911 pps.
# INFO:mlp.optimisers:Epoch 12: Training cost (ce) is 0.551. Accuracy is 86.76%
# INFO:mlp.optimisers:Epoch 12: Validation cost (ce) is 0.497. Accuracy is 88.33%
# INFO:mlp.optimisers:Epoch 12: Took 4 seconds. Training speed 12871 pps. Validation speed 83523 pps.
# INFO:mlp.optimisers:Epoch 13: Training cost (ce) is 0.525. Accuracy is 87.16%
# INFO:mlp.optimisers:Epoch 13: Validation cost (ce) is 0.475. Accuracy is 88.63%
# INFO:mlp.optimisers:Epoch 13: Took 4 seconds. Training speed 12902 pps. Validation speed 83551 pps.
# INFO:mlp.optimisers:Epoch 14: Training cost (ce) is 0.503. Accuracy is 87.55%
# INFO:mlp.optimisers:Epoch 14: Validation cost (ce) is 0.455. Accuracy is 88.92%
# INFO:mlp.optimisers:Epoch 14: Took 4 seconds. Training speed 12910 pps. Validation speed 83512 pps.
# INFO:mlp.optimisers:Epoch 15: Training cost (ce) is 0.484. Accuracy is 87.80%
# INFO:mlp.optimisers:Epoch 15: Validation cost (ce) is 0.438. Accuracy is 89.26%
# INFO:mlp.optimisers:Epoch 15: Took 4 seconds. Training speed 12870 pps. Validation speed 86638 pps.
# INFO:mlp.optimisers:Epoch 16: Training cost (ce) is 0.468. Accuracy is 88.05%
# INFO:mlp.optimisers:Epoch 16: Validation cost (ce) is 0.424. Accuracy is 89.43%
# INFO:mlp.optimisers:Epoch 16: Took 4 seconds. Training speed 12895 pps. Validation speed 83472 pps.
# INFO:mlp.optimisers:Epoch 17: Training cost (ce) is 0.454. Accuracy is 88.34%
# INFO:mlp.optimisers:Epoch 17: Validation cost (ce) is 0.411. Accuracy is 89.58%
# INFO:mlp.optimisers:Epoch 17: Took 4 seconds. Training speed 12720 pps. Validation speed 82935 pps.
# INFO:mlp.optimisers:Epoch 18: Training cost (ce) is 0.441. Accuracy is 88.48%
# INFO:mlp.optimisers:Epoch 18: Validation cost (ce) is 0.400. Accuracy is 89.72%
# INFO:mlp.optimisers:Epoch 18: Took 4 seconds. Training speed 12823 pps. Validation speed 85632 pps.
# INFO:mlp.optimisers:Epoch 19: Training cost (ce) is 0.430. Accuracy is 88.68%
# INFO:mlp.optimisers:Epoch 19: Validation cost (ce) is 0.391. Accuracy is 89.84%
# INFO:mlp.optimisers:Epoch 19: Took 4 seconds. Training speed 12770 pps. Validation speed 85855 pps.
# INFO:mlp.optimisers:Epoch 20: Training cost (ce) is 0.420. Accuracy is 88.85%
# INFO:mlp.optimisers:Epoch 20: Validation cost (ce) is 0.382. Accuracy is 89.94%
# INFO:mlp.optimisers:Epoch 20: Took 4 seconds. Training speed 12869 pps. Validation speed 86906 pps.
# INFO:mlp.optimisers:Epoch 21: Training cost (ce) is 0.411. Accuracy is 89.02%
# INFO:mlp.optimisers:Epoch 21: Validation cost (ce) is 0.374. Accuracy is 90.23%
# INFO:mlp.optimisers:Epoch 21: Took 4 seconds. Training speed 12898 pps. Validation speed 83597 pps.
# INFO:mlp.optimisers:Epoch 22: Training cost (ce) is 0.403. Accuracy is 89.18%
# INFO:mlp.optimisers:Epoch 22: Validation cost (ce) is 0.367. Accuracy is 90.36%
# INFO:mlp.optimisers:Epoch 22: Took 4 seconds. Training speed 12903 pps. Validation speed 83448 pps.
# INFO:mlp.optimisers:Epoch 23: Training cost (ce) is 0.396. Accuracy is 89.27%
# INFO:mlp.optimisers:Epoch 23: Validation cost (ce) is 0.360. Accuracy is 90.40%
# INFO:mlp.optimisers:Epoch 23: Took 4 seconds. Training speed 12795 pps. Validation speed 83395 pps.
# INFO:mlp.optimisers:Epoch 24: Training cost (ce) is 0.389. Accuracy is 89.42%
# INFO:mlp.optimisers:Epoch 24: Validation cost (ce) is 0.355. Accuracy is 90.57%
# INFO:mlp.optimisers:Epoch 24: Took 4 seconds. Training speed 12828 pps. Validation speed 83218 pps.
# INFO:mlp.optimisers:Epoch 25: Training cost (ce) is 0.383. Accuracy is 89.54%
# INFO:mlp.optimisers:Epoch 25: Validation cost (ce) is 0.349. Accuracy is 90.51%
# INFO:mlp.optimisers:Epoch 25: Took 4 seconds. Training speed 12852 pps. Validation speed 77212 pps.
# INFO:mlp.optimisers:Epoch 26: Training cost (ce) is 0.377. Accuracy is 89.65%
# INFO:mlp.optimisers:Epoch 26: Validation cost (ce) is 0.344. Accuracy is 90.76%
# INFO:mlp.optimisers:Epoch 26: Took 4 seconds. Training speed 12839 pps. Validation speed 86246 pps.
# INFO:mlp.optimisers:Epoch 27: Training cost (ce) is 0.372. Accuracy is 89.76%
# INFO:mlp.optimisers:Epoch 27: Validation cost (ce) is 0.340. Accuracy is 90.72%
# INFO:mlp.optimisers:Epoch 27: Took 4 seconds. Training speed 12876 pps. Validation speed 85820 pps.
# INFO:mlp.optimisers:Epoch 28: Training cost (ce) is 0.367. Accuracy is 89.87%
# INFO:mlp.optimisers:Epoch 28: Validation cost (ce) is 0.335. Accuracy is 90.77%
# INFO:mlp.optimisers:Epoch 28: Took 4 seconds. Training speed 12858 pps. Validation speed 82691 pps.
# INFO:mlp.optimisers:Epoch 29: Training cost (ce) is 0.363. Accuracy is 89.96%
# INFO:mlp.optimisers:Epoch 29: Validation cost (ce) is 0.331. Accuracy is 90.94%
# INFO:mlp.optimisers:Epoch 29: Took 4 seconds. Training speed 12758 pps. Validation speed 85583 pps.
# INFO:mlp.optimisers:Epoch 30: Training cost (ce) is 0.358. Accuracy is 90.05%
# INFO:mlp.optimisers:Epoch 30: Validation cost (ce) is 0.328. Accuracy is 90.92%
# INFO:mlp.optimisers:Epoch 30: Took 4 seconds. Training speed 13024 pps. Validation speed 80864 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 90.64 % (cost is 0.338)

# %% [markdown]
# **(b)** (10%) Investigate the impact of different learning rates $\eta \in \{0.5, 0.2, 0.1, 0.05, 0.01, 0.005\}$ on the convergence of the network training as well as the final accuracy:
#    * Plot (on a single graph) the error rate curves for each learning rate as a function of training epochs for training set
#    * Plot (on another single graph) the error rate curves as a function of training epochs for validation set
#    * Include a table of the corresponding error rates for test set
#
# The notebook command `%matplotlib inline` ensures that your graphs will be added to the notebook, rather than opened as additional windows.

# %%
# %matplotlib inline

# include here the complete code that constructs the model, performs training,
# and prints the error and accuracy for train/valid/test

import numpy
import logging
import matplotlib.pyplot as plt

logger = logging.getLogger()
logger.setLevel(logging.WARNING)

from mlp.layers import MLP, Linear, Sigmoid, Softmax #import required layer types
from mlp.optimisers import SGDOptimiser #import the optimiser
from mlp.dataset import MNISTDataProvider #import data provider
from mlp.costs import MSECost, CECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed

etas = [0.5, 0.2, 0.1, 0.05, 0.01, 0.005]
error_rates = []

plt.figure(figsize=(15, 10))

for eta in etas:
    # define the model structure, here just one linear layer
    # and mean square error cost
    cost = CECost()
    model = MLP(cost=cost)
    model.add_layer(Sigmoid(idim=784, odim=100, rng=rng))
    model.add_layer(Softmax(idim=100, odim=10, rng=rng))
    #one can stack more layers here

    # define the optimiser, here stochasitc gradient descent
    # with fixed learning rate and max_epochs as stopping criterion
    lr_scheduler = LearningRateFixed(learning_rate=eta, max_epochs=30)
    optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

    logger.warning('Initialising data providers...')
    train_dp = MNISTDataProvider(dset='train', batch_size=100, max_num_batches=-10, randomize=True)
    valid_dp = MNISTDataProvider(dset='valid', batch_size=100, max_num_batches=-10, randomize=False)

    logger.warning('Training started for eta {0}...'.format(eta))
    training_stats, validation_stats = optimiser.train(model, train_dp, valid_dp)
    
    logger.warning('Testing the model on test set:')
    test_dp = MNISTDataProvider(dset='eval', batch_size=100, max_num_batches=-10, randomize=False)
    cost, accuracy = optimiser.validate(model, test_dp)
    logger.warning('MNIST test set accuracy is %.2f %% (cost is %.3f)'%(accuracy*100., cost))

    error_rates.append(1-accuracy)
    
    plt.subplot(2,1,1)
    train_errors = []
    for training_stat in training_stats:
        train_errors.append(1 - training_stat[1])
    
    plt.plot(train_errors, label="eta = " + str(eta))
    
    plt.subplot(2,1,2)
    validation_errors = []
    for validation_stat in validation_stats:
        validation_errors.append(1 - validation_stat[1])

    plt.plot(validation_errors, label="eta = " + str(eta))
    
plt.subplot(2,1,1)
plt.xlabel("Number of Epocs")
plt.ylabel("Training Error Value")
plt.legend()
plt.grid()

plt.subplot(2,1,2)
plt.xlabel("Number of Epocs")
plt.ylabel("Validation Error Value")
plt.legend()
plt.grid()

plt.show

from IPython.core.display import HTML
text = "<br><table><tr><td><b>Eta</b></td><td><b>Error Rates</b></td></tr>"
for i in range(0, len(error_rates)):
    text = text + "<tr><td>"+ str(etas[i])+"</td><td>" + str(error_rates[i]) + "</td></tr>"
text = text + "</table>"
HTML(text)
# Out:
# WARNING:root:Initialising data providers...
# WARNING:root:Training started for eta 0.5...
# WARNING:root:Testing the model on test set:
# WARNING:root:MNIST test set accuracy is 97.74 % (cost is 0.077)
# WARNING:root:Initialising data providers...
# WARNING:root:Training started for eta 0.2...
# WARNING:root:Testing the model on test set:
# WARNING:root:MNIST test set accuracy is 96.92 % (cost is 0.102)
# WARNING:root:Initialising data providers...
# WARNING:root:Training started for eta 0.1...
# WARNING:root:Testing the model on test set:
# WARNING:root:MNIST test set accuracy is 95.65 % (cost is 0.148)
# WARNING:root:Initialising data providers...
# WARNING:root:Training started for eta 0.05...
# WARNING:root:Testing the model on test set:
# WARNING:root:MNIST test set accuracy is 94.13 % (cost is 0.207)
# WARNING:root:Initialising data providers...
# WARNING:root:Training started for eta 0.01...
# WARNING:root:Testing the model on test set:
# WARNING:root:MNIST test set accuracy is 90.75 % (cost is 0.338)
# WARNING:root:Initialising data providers...
# WARNING:root:Training started for eta 0.005...
# WARNING:root:Testing the model on test set:
# WARNING:root:MNIST test set accuracy is 88.84 % (cost is 0.448)
# <br><table><tr><td><b>Eta</b></td><td><b>Error Rates</b></td></tr><tr><td>0.5</td><td>0.0226</td></tr><tr><td>0.2</td><td>0.0308</td></tr><tr><td>0.1</td><td>0.0435</td></tr><tr><td>0.05</td><td>0.0587</td></tr><tr><td>0.01</td><td>0.0925</td></tr><tr><td>0.005</td><td>0.1116</td></tr></table>

# %% [markdown]
# **(c)** (10%) Plot the following graphs:
#   * Display the 784-element weight vector of each of the 100 hidden units as 10x10 grid plot of 28x28 images, in order to visualise what features of the input they are encoding.  To do this, take the weight vector of each hidden unit, reshape to 28x28, and plot using the `imshow` function).
#   * Plot a Hinton Diagram of the output layer weight matrix for digits 0 and 1

# %%
# %matplotlib inline

# include here the complete code that constructs the model, performs training,
# and prints the error and accuracy for train/valid/test

import numpy
import logging
import matplotlib.pyplot as plt

logger = logging.getLogger()
logger.setLevel(logging.WARNING)

from mlp.layers import MLP, Linear, Sigmoid, Softmax #import required layer types
from mlp.optimisers import SGDOptimiser #import the optimiser
from mlp.dataset import MNISTDataProvider #import data provider
from mlp.costs import MSECost, CECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed

# define the model structure, here just one linear layer
# and mean square error cost
cost = CECost()
model = MLP(cost=cost)
model.add_layer(Sigmoid(idim=784, odim=100, rng=rng))
model.add_layer(Softmax(idim=100, odim=10, rng=rng))
#one can stack more layers here

# define the optimiser, here stochasitc gradient descent
# with fixed learning rate and max_epochs as stopping criterion
lr_scheduler = LearningRateFixed(learning_rate=0.5, max_epochs=30)
optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

logger.warning('Initialising data providers...')
train_dp = MNISTDataProvider(dset='train', batch_size=100, max_num_batches=-10, randomize=True)
valid_dp = MNISTDataProvider(dset='valid', batch_size=100, max_num_batches=-10, randomize=False)

logger.warning('Training started...')
training_stats, validation_stats = optimiser.train(model, train_dp, valid_dp)

logger.warning('Testing the model on test set:')
test_dp = MNISTDataProvider(dset='eval', batch_size=100, max_num_batches=-10, randomize=False)
cost, accuracy = optimiser.validate(model, test_dp)
logger.warning('MNIST test set accuracy is %.2f %% (cost is %.3f)'%(accuracy*100., cost))
# Out:
# WARNING:root:Initialising data providers...
# WARNING:root:Training started...
# WARNING:root:Testing the model on test set:
# WARNING:root:MNIST test set accuracy is 97.71 % (cost is 0.076)

# %%
import matplotlib.cm as cm


"""
hinton method adapted from http://matplotlib.org/examples/specialty_plots/hinton_demo.html
"""
def hinton(matrix, max_weight=None, ax=None):
    """Draw Hinton diagram for visualizing a weight matrix."""
    ax = ax if ax is not None else plt.gca()

    if not max_weight:
        max_weight = numpy.sqrt(2**numpy.ceil(numpy.log(numpy.abs(matrix).max())/numpy.log(2)))
        
    ax.patch.set_facecolor('gray')
    ax.set_aspect('equal', 'box')
    ax.xaxis.set_major_locator(plt.NullLocator())
    ax.yaxis.set_major_locator(plt.NullLocator())

    for (x,y),w in numpy.ndenumerate(matrix):
        color = 'white' if w > 0 else 'black'
        size = numpy.sqrt(numpy.abs(w))/max_weight
        rect = plt.Rectangle([x - size / 2, y - size / 2], size, size,
                             facecolor=color, edgecolor=color)
        ax.add_patch(rect)

    ax.autoscale_view()
    ax.invert_yaxis()


figure, axis = plt.subplots(10,10, figsize=(15,15))
for i in range(0,10):
    for j in range(0,10):
        inputs = []
        for weight in model.layers[0].W:
            inputs.append(weight[i * 10 + j])
        inputs = numpy.array(inputs)
        axis[i,j].imshow(inputs.reshape(28,28), cmap = cm.Greys_r)
plt.show()

figure2, axis2 = plt.subplots(1,2, figsize=(10,10))
inputs2 = []
for i in [0, 1]:
    inputs2 = model.layers[1].W.T[i]
    hinton(inputs2.reshape(10,10), ax=axis2[i])
plt.show()

# %% [markdown]
# ## Task 4 - Experiments with 1-5 hidden layers (30%)
#
# In this task use the learning rate which resulted in the best accuracy in your experiments in Task 3 (b).  Perform the following experiments:
#
#   * Train a similar model to Task 3, with one hidden layer, but with 800 hidden units.
#   * Train 4 additional models with 2, 3, 4 and 5 hidden layers.  Set the number of hidden units for each model, such that all the models have similar number of trainable weights ($\pm$2%).   For simplicity, for a given model, keep the number of units in each hidden layer the same.
#   * Plot value of the error function for training and validation sets as a function of training epochs for each model
#   * Plot the test set classification accuracy as a function of the number of hidden layers

# %%
# include here the complete code that constructs the model, performs training,
# and prints the error and accuracy for train/valid/test

import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

from mlp.layers import MLP, Linear, Sigmoid, Softmax #import required layer types
from mlp.optimisers import SGDOptimiser #import the optimiser
from mlp.dataset import MNISTDataProvider #import data provider
from mlp.costs import MSECost, CECost #import the cost we want to use for optimisation
from mlp.schedulers import LearningRateFixed

error_rates = []
plt.figure(figsize=(15, 10))

for i in range(1,6):
    # define the model structure, here just one linear layer
    # and mean square error cost
    cost = CECost()
    model = MLP(cost=cost)
    
    if i == 1:
        model.add_layer(Sigmoid(idim=784, odim=800, rng=rng))
        model.add_layer(Softmax(idim=800, odim=10, rng=rng))
    elif i == 2:
        model.add_layer(Sigmoid(idim=784, odim=493, rng=rng))
        model.add_layer(Sigmoid(idim=493, odim=493, rng=rng))
        model.add_layer(Softmax(idim=493, odim=10, rng=rng))
    elif i == 3:
        model.add_layer(Sigmoid(idim=784, odim=398, rng=rng))
        model.add_layer(Sigmoid(idim=398, odim=398, rng=rng))
        model.add_layer(Sigmoid(idim=398, odim=398, rng=rng))
        model.add_layer(Softmax(idim=398, odim=10, rng=rng))
    elif i == 4:
        model.add_layer(Sigmoid(idim=784, odim=346, rng=rng))
        model.add_layer(Sigmoid(idim=346, odim=346, rng=rng))
        model.add_layer(Sigmoid(idim=346, odim=346, rng=rng))
        model.add_layer(Sigmoid(idim=346, odim=346, rng=rng))
        model.add_layer(Softmax(idim=346, odim=10, rng=rng))
    elif i == 5:
        model.add_layer(Sigmoid(idim=784, odim=311, rng=rng))
        model.add_layer(Sigmoid(idim=311, odim=311, rng=rng))
        model.add_layer(Sigmoid(idim=311, odim=311, rng=rng))
        model.add_layer(Sigmoid(idim=311, odim=311, rng=rng))
        model.add_layer(Sigmoid(idim=311, odim=311, rng=rng))
        model.add_layer(Softmax(idim=311, odim=10, rng=rng))
    
    # define the optimiser, here stochasitc gradient descent
    # with fixed learning rate and max_epochs as stopping criterion
    lr_scheduler = LearningRateFixed(learning_rate=0.5, max_epochs=4)
    optimiser = SGDOptimiser(lr_scheduler=lr_scheduler)

    logger.info('Initialising data providers...')
    train_dp = MNISTDataProvider(dset='train', batch_size=100, max_num_batches=-10, randomize=True)
    valid_dp = MNISTDataProvider(dset='valid', batch_size=100, max_num_batches=-10, randomize=False)

    logger.warning('Training started for model with {0} hidden layers...'.format(i))
    training_stats, validation_stats = optimiser.train(model, train_dp, valid_dp)

    logger.info('Testing the model on test set:')
    test_dp = MNISTDataProvider(dset='eval', batch_size=100, max_num_batches=-10, randomize=False)
    cost, accuracy = optimiser.validate(model, test_dp)
    logger.info('MNIST test set accuracy is %.2f %% (cost is %.3f)'%(accuracy*100., cost))
    
    error_rates.append(1-accuracy)
    
    plt.subplot(2,1,1)
    train_errors = []
    for training_stat in training_stats:
        train_errors.append(1 - training_stat[1])
    
    plt.plot(train_errors, label="Number of Hidden Layers = " + str(i))
    
    plt.subplot(2,1,2)
    validation_errors = []
    for validation_stat in validation_stats:
        validation_errors.append(1 - validation_stat[1])

    plt.plot(validation_errors, label="Number of Hidden Layers = " + str(i))
    
plt.subplot(2,1,1)
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Training Error Value")
plt.legend()
plt.grid()

plt.subplot(2,1,2)
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Validation Error Value")
plt.legend()
plt.grid()

plt.show
# Out:
# INFO:root:Initialising data providers...
# WARNING:root:Training started for model with 1 hidden layers...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for random model is 2.434. Accuracy is 10.21%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for random model is 2.423. Accuracy is 10.31%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 0.784. Accuracy is 83.93%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 0.291. Accuracy is 91.36%
# INFO:mlp.optimisers:Epoch 1: Took 38 seconds. Training speed 1353 pps. Validation speed 6938 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 91.67 % (cost is 0.295)
# INFO:root:Initialising data providers...
# WARNING:root:Training started for model with 2 hidden layers...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for random model is 2.549. Accuracy is 9.86%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for random model is 2.545. Accuracy is 9.91%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 1.096. Accuracy is 64.68%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 0.361. Accuracy is 89.45%
# INFO:mlp.optimisers:Epoch 1: Took 41 seconds. Training speed 1258 pps. Validation speed 6873 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 88.79 % (cost is 0.374)
# INFO:root:Initialising data providers...
# WARNING:root:Training started for model with 3 hidden layers...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for random model is 2.490. Accuracy is 9.98%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for random model is 2.497. Accuracy is 9.61%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 2.110. Accuracy is 21.99%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 1.091. Accuracy is 60.09%
# INFO:mlp.optimisers:Epoch 1: Took 42 seconds. Training speed 1224 pps. Validation speed 8399 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 59.71 % (cost is 1.108)
# INFO:root:Initialising data providers...
# WARNING:root:Training started for model with 4 hidden layers...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for random model is 2.350. Accuracy is 11.36%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for random model is 2.355. Accuracy is 10.64%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 2.335. Accuracy is 10.73%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 2.303. Accuracy is 10.64%
# INFO:mlp.optimisers:Epoch 1: Took 43 seconds. Training speed 1184 pps. Validation speed 8516 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 11.35 % (cost is 2.301)
# INFO:root:Initialising data providers...
# WARNING:root:Training started for model with 5 hidden layers...
# INFO:mlp.optimisers:Epoch 0: Training cost (ce) for random model is 2.418. Accuracy is 9.01%
# INFO:mlp.optimisers:Epoch 0: Validation cost (ce) for random model is 2.411. Accuracy is 9.15%
# INFO:mlp.optimisers:Epoch 1: Training cost (ce) is 2.336. Accuracy is 10.56%
# INFO:mlp.optimisers:Epoch 1: Validation cost (ce) is 2.306. Accuracy is 10.64%
# INFO:mlp.optimisers:Epoch 1: Took 45 seconds. Training speed 1139 pps. Validation speed 9375 pps.
# INFO:root:Testing the model on test set:
# INFO:root:MNIST test set accuracy is 11.35 % (cost is 2.304)
# <function matplotlib.pyplot.show>

# %% [markdown]
# This is the end of coursework 1.
#
# Please remember to save your notebook, and submit your notebook following the instructions at the top.  Please make sure that you have executed all the code cells when you submit the notebook.
